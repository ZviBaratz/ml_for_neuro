# %% [markdown]
# # Exercise I: Exploratory Data Analysis (EDA)

# %% [markdown]
# In our first exercise, we will explore a public dataset of Coronavirus PCR tests based on a fascinating [blog post](https://blog.mafatchallenge.com/2020/04/30/covid-19-testing-with-ml-part-2/) published as part of the [MAFAT Challenge](https://mafatchallenge.mod.gov.il/).
#
# The purpose of this exercise is to demonstrate the importance of inspecting data and understanding it before trying to do anything fancy. As elementary as it may sound, this preliminary step is the pitfall of many data analysis pipelines and nurturing an instinct for visualizing and organizing your raw data will pay off tremendously both in the process of developing and in evaluating the robustness of your models.
#
# We'll start things off by summarizing some key information about the dataset:
#
# * The dataset is shared as [a GitHub repository](https://github.com/mdcollab/covidclinicaldata) containing a directory of CSV files.
# * It is collected by two US-based companies providing services in the health industry.
# * The number of observations is still relatively small, but more are added weekly and the quality of the data is high (there are many features to work with and it is relatively organized and "clean").
# * There are also chest X-rays available for some of the patients, that were not included in this analysis.
#
# So far so good, let's get to work.

# %% [markdown]
# ## Data Retrieval

# %% [markdown]
# In order to keep things orderly and easy to maintain, we will first create a file with some general configurations:

# %% [markdown]
# ````{toggle} configuration.py
#     :show:
# ```{literalinclude} configuration.py
# ```
# ````

# %% [markdown]
# And then write a short module to create a `read_data()` method:

# %% [markdown]
# ````{admonition} Technical Note: remove_x_ray_columns
#     :class: dropdown, tip
# ```{literalinclude} read_data.py
#     :pyobject: remove_x_ray_columns
# ```
# ````

# %% [markdown]
# ````{toggle}
#     :show:
#
# ```{literalinclude} read_data.py
#     :pyobject: read_data
# ```
# ````

# %%
from read_data import read_data

# %% [markdown]
# Now we can read the data by simply running:

# %%
data = read_data()

# %% [markdown]
# ## Raw Inspection

# %% [markdown]
# ````{admonition} Technical Note: get_scattered_chunks
#     :class: dropdown, tip
# ```{literalinclude} get_scattered_chunks.py
# ```
# ````

# %%
from get_scattered_chunks import get_scattered_chunks

# %% [markdown]
# ````{admonition} Technical Note: print_table
#     :class: dropdown, tip
# We will prepare a function to make the styling of the printed dataframe better suited for our purposes:
# ```{literalinclude} print_table.py
# ```
# ```{tip}
# For more information about styling Pandas dataframes, see [the documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html).
# ```
# ````

# %%
from print_table import print_table

# %%
data_chunks = get_scattered_chunks(data, n_chunks=5, chunk_size=3)
print_table(data_chunks)
# Out:
# <style  type="text/css" >
#     #T_16f45_ th {
#           font-size: 12px;
#     }    #T_16f45_ td {
#           font-size: 11px;
#     }#T_16f45_row0_col0,#T_16f45_row0_col1,#T_16f45_row0_col3,#T_16f45_row0_col4,#T_16f45_row0_col6,#T_16f45_row0_col7,#T_16f45_row0_col8,#T_16f45_row0_col9,#T_16f45_row0_col10,#T_16f45_row0_col11,#T_16f45_row0_col12,#T_16f45_row0_col13,#T_16f45_row0_col14,#T_16f45_row0_col15,#T_16f45_row0_col16,#T_16f45_row0_col17,#T_16f45_row0_col18,#T_16f45_row0_col19,#T_16f45_row0_col22,#T_16f45_row0_col23,#T_16f45_row0_col24,#T_16f45_row0_col25,#T_16f45_row0_col26,#T_16f45_row0_col27,#T_16f45_row0_col28,#T_16f45_row0_col30,#T_16f45_row0_col32,#T_16f45_row0_col33,#T_16f45_row0_col34,#T_16f45_row0_col35,#T_16f45_row0_col36,#T_16f45_row0_col37,#T_16f45_row0_col38,#T_16f45_row0_col39,#T_16f45_row0_col40,#T_16f45_row1_col0,#T_16f45_row1_col1,#T_16f45_row1_col3,#T_16f45_row1_col4,#T_16f45_row1_col6,#T_16f45_row1_col7,#T_16f45_row1_col8,#T_16f45_row1_col9,#T_16f45_row1_col10,#T_16f45_row1_col11,#T_16f45_row1_col12,#T_16f45_row1_col13,#T_16f45_row1_col14,#T_16f45_row1_col15,#T_16f45_row1_col16,#T_16f45_row1_col17,#T_16f45_row1_col18,#T_16f45_row1_col19,#T_16f45_row1_col22,#T_16f45_row1_col23,#T_16f45_row1_col24,#T_16f45_row1_col25,#T_16f45_row1_col27,#T_16f45_row1_col28,#T_16f45_row1_col29,#T_16f45_row1_col30,#T_16f45_row1_col32,#T_16f45_row1_col33,#T_16f45_row1_col34,#T_16f45_row1_col35,#T_16f45_row1_col36,#T_16f45_row1_col37,#T_16f45_row1_col38,#T_16f45_row1_col39,#T_16f45_row1_col40,#T_16f45_row2_col0,#T_16f45_row2_col1,#T_16f45_row2_col3,#T_16f45_row2_col6,#T_16f45_row2_col7,#T_16f45_row2_col8,#T_16f45_row2_col9,#T_16f45_row2_col10,#T_16f45_row2_col11,#T_16f45_row2_col12,#T_16f45_row2_col13,#T_16f45_row2_col14,#T_16f45_row2_col15,#T_16f45_row2_col16,#T_16f45_row2_col17,#T_16f45_row2_col18,#T_16f45_row2_col19,#T_16f45_row2_col27,#T_16f45_row2_col40,#T_16f45_row3_col0,#T_16f45_row3_col1,#T_16f45_row3_col3,#T_16f45_row3_col4,#T_16f45_row3_col5,#T_16f45_row3_col6,#T_16f45_row3_col7,#T_16f45_row3_col8,#T_16f45_row3_col9,#T_16f45_row3_col10,#T_16f45_row3_col11,#T_16f45_row3_col12,#T_16f45_row3_col13,#T_16f45_row3_col14,#T_16f45_row3_col15,#T_16f45_row3_col16,#T_16f45_row3_col17,#T_16f45_row3_col18,#T_16f45_row3_col19,#T_16f45_row3_col22,#T_16f45_row3_col27,#T_16f45_row3_col29,#T_16f45_row3_col30,#T_16f45_row3_col32,#T_16f45_row3_col33,#T_16f45_row3_col34,#T_16f45_row3_col35,#T_16f45_row3_col36,#T_16f45_row3_col37,#T_16f45_row3_col38,#T_16f45_row3_col39,#T_16f45_row4_col0,#T_16f45_row4_col1,#T_16f45_row4_col3,#T_16f45_row4_col4,#T_16f45_row4_col5,#T_16f45_row4_col6,#T_16f45_row4_col7,#T_16f45_row4_col8,#T_16f45_row4_col9,#T_16f45_row4_col10,#T_16f45_row4_col11,#T_16f45_row4_col12,#T_16f45_row4_col13,#T_16f45_row4_col14,#T_16f45_row4_col15,#T_16f45_row4_col16,#T_16f45_row4_col17,#T_16f45_row4_col18,#T_16f45_row4_col19,#T_16f45_row4_col23,#T_16f45_row4_col24,#T_16f45_row4_col25,#T_16f45_row4_col27,#T_16f45_row4_col29,#T_16f45_row4_col30,#T_16f45_row4_col32,#T_16f45_row4_col33,#T_16f45_row4_col34,#T_16f45_row4_col35,#T_16f45_row4_col36,#T_16f45_row4_col37,#T_16f45_row4_col38,#T_16f45_row4_col39,#T_16f45_row5_col0,#T_16f45_row5_col1,#T_16f45_row5_col3,#T_16f45_row5_col4,#T_16f45_row5_col5,#T_16f45_row5_col6,#T_16f45_row5_col7,#T_16f45_row5_col8,#T_16f45_row5_col9,#T_16f45_row5_col10,#T_16f45_row5_col11,#T_16f45_row5_col12,#T_16f45_row5_col13,#T_16f45_row5_col14,#T_16f45_row5_col15,#T_16f45_row5_col16,#T_16f45_row5_col17,#T_16f45_row5_col18,#T_16f45_row5_col19,#T_16f45_row5_col23,#T_16f45_row5_col24,#T_16f45_row5_col25,#T_16f45_row5_col26,#T_16f45_row5_col27,#T_16f45_row5_col29,#T_16f45_row5_col30,#T_16f45_row5_col32,#T_16f45_row5_col33,#T_16f45_row5_col34,#T_16f45_row5_col35,#T_16f45_row5_col36,#T_16f45_row5_col37,#T_16f45_row5_col38,#T_16f45_row5_col39,#T_16f45_row6_col0,#T_16f45_row6_col1,#T_16f45_row6_col3,#T_16f45_row6_col4,#T_16f45_row6_col5,#T_16f45_row6_col6,#T_16f45_row6_col7,#T_16f45_row6_col8,#T_16f45_row6_col9,#T_16f45_row6_col10,#T_16f45_row6_col11,#T_16f45_row6_col12,#T_16f45_row6_col13,#T_16f45_row6_col14,#T_16f45_row6_col15,#T_16f45_row6_ ...

# %%
from configuration import TARGET_COLUMN_NAME
from myst_nb import glue

target = data[TARGET_COLUMN_NAME]
n_positives = target.sum()

glue("n_observations", len(data), display=False)
glue("n_columns", len(data.columns), display=False)
glue("target_column_name", TARGET_COLUMN_NAME, display=False)
glue("n_positives", n_positives, display=False)

# %% [markdown]
# Alright! Some things that we can already learn about our dataset from this table are:
# * It contains a total of {glue:}`n_observations` observations.
# * There are {glue:}`n_columns` columns with mixed data types (nemeric and categorical).
# * Missing values certainly exist (we can easily spot `nan` entries).
# * The subsample raises a strong suspicion that dataset is imbalanced, i.e. when examining our target variable ({glue:}`target_column_name`) it seems there are far more negative observations than positive ones. A quick `sum()` call reveals that indeed only {glue:}`n_positives` of the {glue:}`n_observations` observations are positive.

# %% [markdown]
# There are at least two more built-in methods we could use to get a better sense of the information contained within each column are. The first is:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93995 entries, 0 to 93994
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   test_name                      93995 non-null  object
#  1   swab_type                      93995 non-null  object
#  2   covid19_test_results           93995 non-null  bool
#  3   age                            93995 non-null  int64
#  4   high_risk_exposure_occupation  93826 non-null  object
#  5   high_risk_interactions         69168 non-null  object
#  6   diabetes                       93995 non-null  bool
#  7   chd                            93995 non-null  bool
#  8   htn                            93995 non-null  bool
#  9   cancer                         93995 non-null  bool
#  10  asthma                         93995 non-null  bool
#  11  copd                           93995 non-null  bool
#  12  autoimmune_dis                 93995 non-null  bool
#  13  smoker                         93995 non-null  bool
#  14  temperature                    47542 non-null  float64
#  15  pulse                          48279 non-null  float64
#  16  sys                            46523 non-null  float64
#  17  dia                            46523 non-null  float64
#  18  rr                             41448 non-null  float64
#  19  sats                           47535 non-null  float64
#  20  rapid_flu_results              254 non-null    object
#  21  rapid_strep_results            391 non-null    object
#  22  ctab                           35467 non-null  object
#  23  labored_respiration            48747 non-null  object
#  24  rhonchi                        23344 non-null  object
#  25  wheezes                        27488 non-null  object
#  26  days_since_symptom_onset       15865 non-null  float64
#  27  cough                          93980 non-null  object
#  28  cough_severity                 5711 non-null   object
#  29  fever                          71074 non-null  object
#  30  sob                            93789 non-null  object
#  31  sob_severity                   2836 non-null   object
#  32  diarrhea                       93808 non-null  object
#  33  fatigue                        93819 non-null  object
#  34  headache                       93812 non-null  object
#  35  loss_of_smell                  93805 non-null  object
#  36  loss_of_taste                  93805 non-null  object
#  37  runny_nose                     93808 non-null  object
#  38  muscle_sore                    93813 non-null  object
#  39  sore_throat                    93812 non-null  object
#  40  er_referral                    11169 non-null  object
# dtypes: bool(9), float64(7), int64(1), object(24)
# memory usage: 24.5+ MB

# %%
n_categorial = len(data.select_dtypes(["object", "bool"]).columns) - 1
n_features = len(data.columns) - 1
glue("n_categorical", n_categorial, display=False)
glue("n_features", n_features, display=False)

# %% [markdown]
# This simple table allows us to easily infer that:
# * Most ({glue:}`n_categorical`/{glue:}`n_features`) of the collected features are categorial (their data type is `object` or `bool`).
# * Some features contain relatively few non-null values.

# %% [markdown]
# Another useful method we can use is:

# %%
data.describe()
# Out:
#                age   temperature         pulse           sys           dia  \
# count  93995.00000  47542.000000  48279.000000  46523.000000  46523.000000
# mean      39.17569     36.794765     76.933677    123.149045     78.297079
# std       15.03687      0.289229     13.238270     16.113033      9.464313
# min       -3.00000     33.500000     35.000000     50.000000     15.000000
# 25%       28.00000     36.650000     68.000000    112.000000     72.000000
# 50%       37.00000     36.800000     76.000000    121.000000     78.000000
# 75%       50.00000     36.950000     85.000000    132.000000     84.000000
# max       91.00000     39.600000    160.000000    235.000000    150.000000
#
#                  rr          sats  days_since_symptom_onset
# count  41448.000000  47535.000000              15865.000000
# mean      14.710601     98.238224                  7.063914
# std        1.971628      1.423986                 17.232417
# min        0.000000     55.000000                  1.000000
# 25%       13.000000     97.000000                  2.000000
# 50%       15.000000     98.000000                  3.000000
# 75%       16.000000     99.000000                  7.000000
# max       40.000000    100.000000                300.000000

# %%
from print_table import get_table_styles

table_styles = get_table_styles()
data.describe().style.set_table_styles(table_styles).set_properties(
    **{"text-align": 'center'})
# Out:
# <style  type="text/css" >
#     #T_9f0c8_ th {
#           font-size: 12px;
#     }    #T_9f0c8_ td {
#           font-size: 11px;
#     }#T_9f0c8_row0_col0,#T_9f0c8_row0_col1,#T_9f0c8_row0_col2,#T_9f0c8_row0_col3,#T_9f0c8_row0_col4,#T_9f0c8_row0_col5,#T_9f0c8_row0_col6,#T_9f0c8_row0_col7,#T_9f0c8_row1_col0,#T_9f0c8_row1_col1,#T_9f0c8_row1_col2,#T_9f0c8_row1_col3,#T_9f0c8_row1_col4,#T_9f0c8_row1_col5,#T_9f0c8_row1_col6,#T_9f0c8_row1_col7,#T_9f0c8_row2_col0,#T_9f0c8_row2_col1,#T_9f0c8_row2_col2,#T_9f0c8_row2_col3,#T_9f0c8_row2_col4,#T_9f0c8_row2_col5,#T_9f0c8_row2_col6,#T_9f0c8_row2_col7,#T_9f0c8_row3_col0,#T_9f0c8_row3_col1,#T_9f0c8_row3_col2,#T_9f0c8_row3_col3,#T_9f0c8_row3_col4,#T_9f0c8_row3_col5,#T_9f0c8_row3_col6,#T_9f0c8_row3_col7,#T_9f0c8_row4_col0,#T_9f0c8_row4_col1,#T_9f0c8_row4_col2,#T_9f0c8_row4_col3,#T_9f0c8_row4_col4,#T_9f0c8_row4_col5,#T_9f0c8_row4_col6,#T_9f0c8_row4_col7,#T_9f0c8_row5_col0,#T_9f0c8_row5_col1,#T_9f0c8_row5_col2,#T_9f0c8_row5_col3,#T_9f0c8_row5_col4,#T_9f0c8_row5_col5,#T_9f0c8_row5_col6,#T_9f0c8_row5_col7,#T_9f0c8_row6_col0,#T_9f0c8_row6_col1,#T_9f0c8_row6_col2,#T_9f0c8_row6_col3,#T_9f0c8_row6_col4,#T_9f0c8_row6_col5,#T_9f0c8_row6_col6,#T_9f0c8_row6_col7,#T_9f0c8_row7_col0,#T_9f0c8_row7_col1,#T_9f0c8_row7_col2,#T_9f0c8_row7_col3,#T_9f0c8_row7_col4,#T_9f0c8_row7_col5,#T_9f0c8_row7_col6,#T_9f0c8_row7_col7{
#             text-align:  center;
#         }</style><table id="T_9f0c8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >temperature</th>        <th class="col_heading level0 col2" >pulse</th>        <th class="col_heading level0 col3" >sys</th>        <th class="col_heading level0 col4" >dia</th>        <th class="col_heading level0 col5" >rr</th>        <th class="col_heading level0 col6" >sats</th>        <th class="col_heading level0 col7" >days_since_symptom_onset</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f0c8_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_9f0c8_row0_col0" class="data row0 col0" >93995.000000</td>
#                         <td id="T_9f0c8_row0_col1" class="data row0 col1" >47542.000000</td>
#                         <td id="T_9f0c8_row0_col2" class="data row0 col2" >48279.000000</td>
#                         <td id="T_9f0c8_row0_col3" class="data row0 col3" >46523.000000</td>
#                         <td id="T_9f0c8_row0_col4" class="data row0 col4" >46523.000000</td>
#                         <td id="T_9f0c8_row0_col5" class="data row0 col5" >41448.000000</td>
#                         <td id="T_9f0c8_row0_col6" class="data row0 col6" >47535.000000</td>
#                         <td id="T_9f0c8_row0_col7" class="data row0 col7" >15865.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9f0c8_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_9f0c8_row1_col0" class="data row1 col0" >39.175690</td>
#                         <td id="T_9f0c8_row1_col1" class="data row1 col1" >36.794765</td>
#                         <td id="T_9f0c8_row1_col2" class="data row1 col2" >76.933677</td>
#                         <td id="T_9f0c8_row1_col3" class="data row1 col3" >123.149045</td>
#                         <td id="T_9f0c8_row1_col4" class="data row1 col4" >78.297079</td>
#                         <td id="T_9f0c8_row1_col5" class="data row1 col5" >14.710601</td>
#                         <td id="T_9f0c8_row1_col6" class="data row1 col6" >98.238224</td>
#                         <td id="T_9f0c8_row1_col7" class="data row1 col7" >7.063914</td>
#             </tr>
#             <tr>
#                         <th id="T_9f0c8_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_9f0c8_row2_col0" class="data row2 col0" >15.036870</td>
#                         <td id="T_9f0c8_row2_col1" class="data row2 col1" >0.289229</td>
#                         <td id="T_9f0c8_row2_col2" class="data row2 col2" >13.238270</td>
#                         <td id="T_9f0c8_row2_col3" class="data row2 col3" >16.113033</td>
#                         <td id="T_9f0c8_row2_col4" class="data row2 col4" >9.464313</td>
#                         <td id="T_9f0c8_row2_col5" class="data row2 col5" >1.971628</td>
#                         <td id="T_9f0c8_row2_col6" class="data row2 col6" >1.423986</td>
#                         <td id="T_9f0c8_row2_col7" class="data row2 col7" >17.232417</td>
#             </tr>
#             <tr>
#                         <th id="T_9f0c8_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_9f0c8_row3_col0" class="data row3 col0" >-3.000000</td>
#                         <td id="T_9f0c8_row3_col1" class="data row3 col1" >33.500000</td>
#                         <td id="T_9f0c8_row3_col2" class="data row3 col2" >35.000000</td>
#                         <td id="T_9f0c8_row3_col3" class="data row3 col3" >50.000000</td>
#                         <td id="T_9f0c8_row3_col4" class="data row3 col4" >15.000000</td>
#                         <td id="T_9f0c8_row3_col5" class="data row3 col5" >0.000000</td>
#                         <td id="T_9f0c8_row3_col6" class="data row3 col6" >55.000000</td>
#                         <td id="T_9f0c8_row3_col7" class="data row3 col7" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9f0c8_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_9f0c8_row4_col0" class="data row4 col0" >28.000000</td>
#                         <td id="T_9f0c8_row4_col1" class="data row4 col1" >36.650000</td>
#                         <td id="T_9f0c8_row4_col2" class="data row4 col2" >68.000000</td>
#                         <td id="T_9f0c8_row4_col3" class="data row4 col3" >112.000000</td>
#                         <td id="T_9f0c8_row4_col4" class="data row4 col4" >72.000000</td>
#                         <td id="T_9f0c8_row4_col5" class="data row4 col5" >13.000000</td>
#                         <td id="T_9f0c8_row4_col6" class="data row4 col6" >97.000000</td>
#                         <td id="T_9f0c8_row4_col7" class="data row4 col7" >2.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9f0c8_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_9f0c8_row5_col0" class="data row5 col0" >37.000000</td>
#                         <td id="T_9f0c8_row5_col1" class="data row5 col1" >36.800000</td>
#                         <td id="T_9f0c8_row5_col2" class="data row5 col2" >76.000000</td>
#                         <td id="T_9f0c8_row5_col3" class="data row5 col3" >121.000000</td>
#                         <td id="T_9f0c8_row5_col4" class="data row5 col4" >78.000000</td>
#                         <td id="T_9f0c8_row5_col5" class="data row5 col5" >15.000000</td>
#                         <td id="T_9f0c8_row5_col6" class="data row5 col6" >98.000000</td>
#                         <td id="T_9f0c8_row5_col7" class="data row5 col7" >3.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9f0c8_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_9f0c8_row6_col0" class="data row6 col0" >50.000000</td>
#                         <td id="T_9f0c8_row6_col1" class="data row6 col1" >36.950000</td>
#                         <td id="T_9f0c8_row6_col2" class="data row6 col2" >85.000000</td>
#                         <td id="T_9f0c8_row6_col3" class="data row6 col3" >132.000000</td>
#                         <td id="T_9f0c8_row6_col4" class="data row6 col4" >84.000000</td>
#                         <td id="T_9f0c8_row6_col5" class="data row6 col5" >16.000000</td>
#                         <td id="T_9f0c8_row6_col6" class="data row6 col6" >99.000000</td>
#                         <td id="T_9f0c8_row6_col7" class="data row6 col7" >7.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9f0c8_level0_row7" clas

# %% [markdown]
# This table summarizes the basic properties of each of the numerical columns contained in the dataset and gives a brief overview of the observed variance.

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Handling missing values requires careful judgement. Possible solutions include:
# * Removing the entire feature (column) containing the missing values.
# * Removing all observations with missing values.
# * *Imputation*: "Filling in" missing values with some constant or statistic, such as the mean or the mode.
#
# There is not one correct method - different circumstances call for different approaches, and often there is still room for debate. However, some useful guidelines are:
# * If a column contains a small number of observations (relative to the size of the dataset) and the dataset is rich enough and offers more features that could be expected to be informative, it might be best to remove it.
# * If the dataset is large and the feature in question is crucial for the purposes of our analysis, remove all observations with missing values.
# * Imputation might sound like a good trade-off if there is a good reason to believe some statistic may adequately approximate the missing values, but it is also the subject of many misconceptions and often used poorly.
# * There are also learning methods that can safely include missing values (such as decision trees). We will learn when and how these are used later in this course.
#
# Let's first get a better sense of what fraction of the values is missing in each of the relevant columns in our dataset:

# %% [markdown]
# ````{admonition} Technical Note: calculate_nan_fractions
#     :class: dropdown, tip
# ```{literalinclude} missing_values.py
#     :pyobject: calculate_nan_fractions
# ```
# ````

# %%
from missing_values import calculate_nan_fractions

# %%
missing_fractions_df = calculate_nan_fractions(data)
missing_fractions_df.style.format("{:,.2%}")
# Out:
# <style  type="text/css" >
# </style><table id="T_b5a02_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Missing</th>        <th class="col_heading level0 col1" >Negatives Fraction</th>        <th class="col_heading level0 col2" >Positives Fraction</th>    </tr>    <tr>        <th class="index_name level0" >Column Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5a02_level0_row0" class="row_heading level0 row0" >rapid_flu_results</th>
#                         <td id="T_b5a02_row0_col0" class="data row0 col0" >99.73%</td>
#                         <td id="T_b5a02_row0_col1" class="data row0 col1" >98.62%</td>
#                         <td id="T_b5a02_row0_col2" class="data row0 col2" >1.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row1" class="row_heading level0 row1" >rapid_strep_results</th>
#                         <td id="T_b5a02_row1_col0" class="data row1 col0" >99.58%</td>
#                         <td id="T_b5a02_row1_col1" class="data row1 col1" >98.62%</td>
#                         <td id="T_b5a02_row1_col2" class="data row1 col2" >1.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row2" class="row_heading level0 row2" >sob_severity</th>
#                         <td id="T_b5a02_row2_col0" class="data row2 col0" >96.98%</td>
#                         <td id="T_b5a02_row2_col1" class="data row2 col1" >98.66%</td>
#                         <td id="T_b5a02_row2_col2" class="data row2 col2" >1.34%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row3" class="row_heading level0 row3" >cough_severity</th>
#                         <td id="T_b5a02_row3_col0" class="data row3 col0" >93.92%</td>
#                         <td id="T_b5a02_row3_col1" class="data row3 col1" >98.94%</td>
#                         <td id="T_b5a02_row3_col2" class="data row3 col2" >1.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row4" class="row_heading level0 row4" >er_referral</th>
#                         <td id="T_b5a02_row4_col0" class="data row4 col0" >88.12%</td>
#                         <td id="T_b5a02_row4_col1" class="data row4 col1" >98.80%</td>
#                         <td id="T_b5a02_row4_col2" class="data row4 col2" >1.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row5" class="row_heading level0 row5" >days_since_symptom_onset</th>
#                         <td id="T_b5a02_row5_col0" class="data row5 col0" >83.12%</td>
#                         <td id="T_b5a02_row5_col1" class="data row5 col1" >99.18%</td>
#                         <td id="T_b5a02_row5_col2" class="data row5 col2" >0.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row6" class="row_heading level0 row6" >rhonchi</th>
#                         <td id="T_b5a02_row6_col0" class="data row6 col0" >75.16%</td>
#                         <td id="T_b5a02_row6_col1" class="data row6 col1" >98.98%</td>
#                         <td id="T_b5a02_row6_col2" class="data row6 col2" >1.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row7" class="row_heading level0 row7" >wheezes</th>
#                         <td id="T_b5a02_row7_col0" class="data row7 col0" >70.76%</td>
#                         <td id="T_b5a02_row7_col1" class="data row7 col1" >99.06%</td>
#                         <td id="T_b5a02_row7_col2" class="data row7 col2" >0.94%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row8" class="row_heading level0 row8" >ctab</th>
#                         <td id="T_b5a02_row8_col0" class="data row8 col0" >62.27%</td>
#                         <td id="T_b5a02_row8_col1" class="data row8 col1" >99.27%</td>
#                         <td id="T_b5a02_row8_col2" class="data row8 col2" >0.73%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row9" class="row_heading level0 row9" >rr</th>
#                         <td id="T_b5a02_row9_col0" class="data row9 col0" >55.90%</td>
#                         <td id="T_b5a02_row9_col1" class="data row9 col1" >99.34%</td>
#                         <td id="T_b5a02_row9_col2" class="data row9 col2" >0.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row10" class="row_heading level0 row10" >dia</th>
#                         <td id="T_b5a02_row10_col0" class="data row10 col0" >50.50%</td>
#                         <td id="T_b5a02_row10_col1" class="data row10 col1" >99.48%</td>
#                         <td id="T_b5a02_row10_col2" class="data row10 col2" >0.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row11" class="row_heading level0 row11" >sys</th>
#                         <td id="T_b5a02_row11_col0" class="data row11 col0" >50.50%</td>
#                         <td id="T_b5a02_row11_col1" class="data row11 col1" >99.48%</td>
#                         <td id="T_b5a02_row11_col2" class="data row11 col2" >0.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row12" class="row_heading level0 row12" >sats</th>
#                         <td id="T_b5a02_row12_col0" class="data row12 col0" >49.43%</td>
#                         <td id="T_b5a02_row12_col1" class="data row12 col1" >99.49%</td>
#                         <td id="T_b5a02_row12_col2" class="data row12 col2" >0.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row13" class="row_heading level0 row13" >temperature</th>
#                         <td id="T_b5a02_row13_col0" class="data row13 col0" >49.42%</td>
#                         <td id="T_b5a02_row13_col1" class="data row13 col1" >99.48%</td>
#                         <td id="T_b5a02_row13_col2" class="data row13 col2" >0.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row14" class="row_heading level0 row14" >pulse</th>
#                         <td id="T_b5a02_row14_col0" class="data row14 col0" >48.64%</td>
#                         <td id="T_b5a02_row14_col1" class="data row14 col1" >99.49%</td>
#                         <td id="T_b5a02_row14_col2" class="data row14 col2" >0.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row15" class="row_heading level0 row15" >labored_respiration</th>
#                         <td id="T_b5a02_row15_col0" class="data row15 col0" >48.14%</td>
#                         <td id="T_b5a02_row15_col1" class="data row15 col1" >99.48%</td>
#                         <td id="T_b5a02_row15_col2" class="data row15 col2" >0.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row16" class="row_heading level0 row16" >high_risk_interactions</th>
#                         <td id="T_b5a02_row16_col0" class="data row16 col0" >26.41%</td>
#                         <td id="T_b5a02_row16_col1" class="data row16 col1" >99.05%</td>
#                         <td id="T_b5a02_row16_col2" class="data row16 col2" >0.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row17" class="row_heading level0 row17" >fever</th>
#                         <td id="T_b5a02_row17_col0" class="data row17 col0" >24.39%</td>
#                         <td id="T_b5a02_row17_col1" class="data row17 col1" >99.10%</td>
#                         <td id="T_b5a02_row17_col2" class="data row17 col2" >0.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a02_level0_row18" class="row_heading level0 row18" >sob</th>
#                         <td id="T_b5a02_row18_col0" class="data row18 col0" >0.22%</td>
#                         <td id="T_b5a02_row18_col1" class="data row18 col

# %%
positives_fraction = "{:,.2%}".format(len(data[target]) / len(data))
mean_positives_null_fraction = "{:,.2%}".format(missing_fractions_df["Positives Fraction"].mean())

glue("mean_positives_null_fraction", mean_positives_null_fraction, display=False)
glue("positives_fraction", positives_fraction, display=False)

# %% [markdown]
# This table allows us to see which columns containt a large fraction of missing values, and also shows us that the mean relative fraction of missing values in Coronavirus-positive observations ({glue:}`mean_positives_null_fraction`) isn't far from the general fraction of positives ({glue:}`positives_fraction`). This is a good sign, and while not really proving anything, gives us good reason to believe the the dataset does not include a ["missing not at random"](https://en.wikipedia.org/wiki/Missing_data#Missing_not_at_random) bias.

# %%
from configuration import NAN_FRACTION_THRESHOLD

glue("nan_fraction_threshold", "{:,.2%}".format(NAN_FRACTION_THRESHOLD), display=False)

# %% [markdown]
# Now, we will create a simple function to remove all columns with more than {glue:}`nan_fraction_threshold` of missing values as well as any remaining observations which include missing values:

# %% [markdown]
# ````{admonition} Technical Note: remove_missing_data_columns
#     :class: dropdown, tip
# ```{literalinclude} missing_values.py
#     :pyobject: remove_missing_data_columns
# ```
# ````

# %% [markdown]
# ````{toggle}
#     :show:
# ```{literalinclude} missing_values.py
#     :pyobject: clean_missing_values
# ```
# ````

# %% [markdown]
# And run it:

# %%
from missing_values import clean_missing_values

# %%
data = clean_missing_values(data)

# %% [markdown]
# Our dataset is now clean from any missing values and ready for further inspection.

# %%
X = data.drop(TARGET_COLUMN_NAME, axis=1)

categorial_features = X.select_dtypes(["object", "bool"])
numerical_featuers = X.select_dtypes(exclude=["object", "bool"])

print("Categorial features:\n" + ", ".join(categorial_features.columns))
print("\nNumerical features:\n" + ", ".join(numerical_featuers.columns))
# Out:
# Categorial features:
# test_name, swab_type, high_risk_exposure_occupation, high_risk_interactions, diabetes, chd, htn, cancer, asthma, copd, autoimmune_dis, smoker, labored_respiration, cough, fever, sob, diarrhea, fatigue, headache, loss_of_smell, loss_of_taste, runny_nose, muscle_sore, sore_throat
#
# Numerical features:
# age, temperature, pulse, sats

# %%
n_features_after = len(data.columns) - 1
n_observations_after = len(data)
target = data[TARGET_COLUMN_NAME]
n_positives_after = target.sum()

glue("n_features_after", n_features_after, display=False)
glue("n_observations_after", n_observations_after, display=False)
glue("n_positives_after", n_positives_after, display=False)

# %% [markdown]
# We are left with {glue:}`n_features_after` features and {glue:}`n_observations_after` observations ({glue:}`n_positives_after` of which are positive).

# %% [markdown]
# ### Feature Correlations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = X.corr()
fig, ax = plt.subplots(figsize=(12, 10))
_ = sns.heatmap(correlation_matrix, annot=True)

# %% [markdown]
# ## Categorial Features

# %% [markdown]
# Boolean columns previously containing missing values might have been originally inferred as `object` type columns, we'll use pandas' `convert_dtypes()` method to infer data types again:

# %%
X = X.convert_dtypes()

# %% [markdown]
# Assuming $y$ (a COVID-19 positive patient), what is the probability of each of the features (symptomps):

# %%
import pandas as pd

boolean_features = X.select_dtypes(["bool"])
positives = boolean_features[target]
value_counts = {}
for column in positives:
    value_counts[column] = positives[column].value_counts()
value_counts = pd.DataFrame(value_counts)

fig, ax = plt.subplots(figsize=(15, 5))
_ = value_counts.T.plot(kind="bar", ax=ax)
_ = plt.title("Symptoms in Positive Patients")
_ = ax.set_xlabel("Feature")
_ = ax.set_ylabel("Count")

# %% [markdown]
# To plot the fraction of `True` observations in each of our target groups:

# %%
# Group all boolean features by the target variable (COVID-19 test result)
grouped = boolean_features.groupby(target)

# Calculate the fraction of positives in each group.
fractions = grouped.sum() / grouped.count()

# Create a bar plot.
fig, ax = plt.subplots(figsize=(15, 5))
_ = fractions.T.plot(kind="bar", ax=ax)
_ = plt.title("Fraction of Positive Responses by Test Result")
_ = ax.set_xlabel("Feature")
_ = ax.set_ylabel("Fraction")

# %% [markdown]
# ## Numerical Features

# %%
# Select all numerical features.
numerical_features = X.select_dtypes(["float64", "int64"])

# Create distribution plots.
nrows = len(numerical_features.columns)
fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15, 30))
for i, feature in enumerate(numerical_features):
    sns.violinplot(x=TARGET_COLUMN_NAME, y=feature, data=data, ax=ax[i, 0])
    if i == 0:
        ax[i, 0].set_title("Violin Plots")
        ax[i, 1].set_title("Box Plots")        
    sns.boxplot(x=TARGET_COLUMN_NAME, y=feature, data=data, ax=ax[i, 1])
    ax[i, 0].set_xlabel("")
    ax[i, 1].set_xlabel("")
    ax[i, 1].set_ylabel("")
_ = fig.text(0.5, 0, "COVID-19 Test Results", ha='center')
_ = fig.suptitle("Numerical Feature Distributions", y=1)
fig.tight_layout()

# %% [markdown]
# ```{note}
# [Violin plots](https://en.wikipedia.org/wiki/Violin_plot) are essentially [box plots](https://en.wikipedia.org/wiki/Box_plot) combined with a [kernel density estimation](https://en.wikipedia.org/wiki/Kernel_density_estimation). While box plots give us a good understanding of the data's quartiles and outliers, violin plots provide us with an informative representation of it's entire distribution.
# ```
