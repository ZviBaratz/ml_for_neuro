# %% [markdown]
# # Exercise III: Linear Regression

# %% [markdown]
# > In statistics, linear regression is a linear approach to modeling the relationship between a scalar response (or dependent variable) and one or more explanatory variables (or independent variables). [*Wikipedia*](https://en.wikipedia.org/wiki/Linear_regression)
#
# Using linear regression with Python is as easy as running:
#
# ```python
# >>> from sklearn.linear_model import LinearRegression
# >>> model = LinearRegression()
# >>> model.fit(X_train, y_train)
# >>> predictions = model.predict(X_test)
# ```

# %% [markdown]
# ## Diabetes

# %% [markdown]
# First, let's reproduce `scikit-learn`'s [Linear Regerssion Example](https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html#linear-regression-example) using the prepackaged `diabetes` dataset.

# %% [markdown]
# ### Loading the Dataset

# %%
import pandas as pd

from sklearn import datasets

# Read the dataset as a pandas DataFrame
dataset = datasets.load_diabetes(as_frame=True)

# Create observations matrix and target vector
X, y = dataset.data, dataset.target

# Create a unified DataFrame containing both
data = pd.concat([X, y], axis=1)

# %% [markdown]
# ### Basic Exploration

# %% [markdown]
# #### Dataset Description

# %%
print(dataset.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, T-Cells (a type of white blood cells)
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, thyroid stimulating hormone
#       - s5      ltg, lamotrigine
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %% [markdown]
# #### Raw Inspection

# %%
import numpy as np
import pandas as pd

# Select some sample indices
sample_indices = np.linspace(0, len(X) - 4, 4, dtype=int)
sample_indices = [index for i in sample_indices for index in range(i, i + 4)]

# Print data table (features and target)
data.iloc[sample_indices, :].style.set_properties(**{
    "text-align": "center",
}).set_properties(**{
    "border-left": "4px solid black"
}, subset=['target']).set_table_styles([
    dict(selector="th", props=[("font-size", "13px")]),
    dict(selector="td", props=[("font-size", "11px")]),
]).background_gradient().set_precision(3)
# Out:
# <style  type="text/css" >
#     #T_db9d0af6_2e56_11eb_8714_dfbde11d4e1d th {
#           font-size: 13px;
#     }    #T_db9d0af6_2e56_11eb_8714_dfbde11d4e1d td {
#           font-size: 11px;
#     }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col0,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow4_col9{
#             text-align:  center;
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col3,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col0,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow4_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow5_col2,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow6_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow7_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow7_col7,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow7_col8,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow9_col2,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow10_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow11_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow12_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow12_col5,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow12_col9,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow13_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow15_col4,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow15_col6{
#             text-align:  center;
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col2{
#             text-align:  center;
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col4,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col8{
#             text-align:  center;
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col5,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow7_col0{
#             text-align:  center;
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col6,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow4_col6{
#             text-align:  center;
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col7,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col7,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow6_col7,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow10_col7{
#             text-align:  center;
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col8{
#             text-align:  center;
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col9{
#             text-align:  center;
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow0_col10{
#             text-align:  center;
#             border-left:  4px solid black;
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col0{
#             text-align:  center;
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col9,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow3_col0,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow3_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow5_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow7_col6,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow8_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow8_col4,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow8_col5,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow8_col7,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow9_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow10_col8,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow14_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow15_col1,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow15_col2,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow15_col3{
#             text-align:  center;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col2{
#             text-align:  center;
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col3,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow6_col2{
#             text-align:  center;
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col4{
#             text-align:  center;
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col5,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow4_col0,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow7_col3,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow11_col6{
#             text-align:  center;
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col6{
#             text-align:  center;
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col7,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow11_col7,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow15_col7{
#             text-align:  center;
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow1_col10{
#             text-align:  center;
#             border-left:  4px solid black;
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col2{
#             text-align:  center;
#             background-color:  #157ab5;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col3,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow10_col3{
#             text-align:  center;
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col4{
#             text-align:  center;
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col5{
#             text-align:  center;
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col6,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow10_col6{
#             text-align:  center;
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col8,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow14_col5{
#             text-align:  center;
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col9,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow5_col4,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow14_col9{
#             text-align:  center;
#             background-color:  #79abd0;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow2_col10{
#             text-align:  center;
#             border-left:  4px solid black;
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow3_col2,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow13_col5{
#             text-align:  center;
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow3_col3{
#             text-align:  center;
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow3_col4,#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow4_col4{
#             text-align:  center;
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow3_col5{
#             text-align:  center;
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_db9d0af6_2e56_11eb_8714_dfbde11d4e1drow3_col6,#T_db9d0af6_2e56_11eb

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
pd.set_option('float_format', '{:g}'.format)
data.describe()
# Out:
#                age         sex          bmi          bp           s1  \
# count          442         442          442         442          442
# mean  -3.63962e-16 1.30991e-16 -8.01395e-16 1.28982e-16 -9.04254e-17
# std       0.047619    0.047619     0.047619    0.047619     0.047619
# min      -0.107226  -0.0446416   -0.0902753     -0.1124    -0.126781
# 25%     -0.0372993  -0.0446416   -0.0342291  -0.0366564   -0.0342478
# 50%     0.00538306  -0.0446416  -0.00728377 -0.00567061  -0.00432087
# 75%      0.0380759   0.0506801     0.031248   0.0356438     0.028358
# max       0.110727   0.0506801     0.170555    0.132044     0.153914
#
#                s2           s3          s4          s5           s6  target
# count         442          442         442         442          442     442
# mean  1.30112e-16 -4.56397e-16 3.86317e-16 -3.8481e-16 -3.39849e-16 152.133
# std      0.047619     0.047619    0.047619    0.047619     0.047619  77.093
# min     -0.115613    -0.102307  -0.0763945   -0.126097    -0.137767      25
# 25%    -0.0303584   -0.0351172  -0.0394934  -0.0332488    -0.033179      87
# 50%   -0.00381907  -0.00658447 -0.00259226 -0.00194763   -0.0010777   140.5
# 75%     0.0298444    0.0293115   0.0343089   0.0324332    0.0279171   211.5
# max      0.198788     0.181179    0.185234    0.133599     0.135612     346

# %% [markdown]
# #### Scatter Matrix

# %%
import matplotlib.pyplot as plt

# Extract numeric data
numeric_data = data.drop(["sex"], axis=1)

# Plot scatter matrix
axes = pd.plotting.scatter_matrix(numeric_data, figsize=(15, 15))

# Fix y-axis label formatting
new_labels = [
    round(float(i.get_text()), 2) for i in axes[0, 0].get_yticklabels()
]
_ = axes[0, 0].set_yticklabels(new_labels)

# %% [markdown]
# #### Feature Correlation

# %% [markdown]
# We can use `seaborn`'s [`heatmap`](http://seaborn.pydata.org/generated/seaborn.heatmap.html) function to inspect feature correlations.

# %%
import seaborn as sns

# Calculate correlation matrix using NumPy
correlation_matrix = np.corrcoef(data.values.T)

# Plot correlation matrix using seaborn
fig, ax = plt.subplots(figsize=(8, 8))
tick_labels = list(X.columns) + ['diabetes']
hm = sns.heatmap(
    correlation_matrix,
    ax=ax,
    cbar=True,  # Show colorbar
    cmap="vlag",  # Specify colormap
    vmin=-1,  # Min. value for colormapping
    vmax=1,  # Max. value for colormapping
    annot=True,  # Show the value of each cell
    square=True,  # Square aspect ratio in cell sizing
    fmt='.2f',  # Float formatting
    annot_kws={'size':
               12},  # Font size of the values displayed within the cells
    xticklabels=tick_labels,  # x-axis labels
    yticklabels=tick_labels)  # y-axis labels
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Simple Linear Regression

# %% [markdown]
# Simple linear regression is a linear regression model with a single explanatory variable. `bmi` seems to show a discernible linear relationship with the target variable, so let's go with that one.

# %% [markdown]
# #### Train/Test Split

# %%
from sklearn.model_selection import train_test_split

# Create a vector of the single predictor values
simple_X = X.bmi.to_numpy().reshape(len(X), 1)

# Split for simple linear regression
simple_X_train, simple_X_test, y_train, y_test = train_test_split(simple_X,
                                                                  y,
                                                                  random_state=0,
                                                                  test_size=0.2)

# Split for multiple linear regression
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=0,
                                                    test_size=0.2)

# %%
from myst_nb import glue

glue("n_train_diabetes", len(simple_X_train), display=False)
glue("n_test_diabetes", len(simple_X_test), display=False)

# %% [markdown]
# We now have a training dataset consisting of {glue:}`n_train_diabetes` observations and a test dataset with {glue:}`n_test_diabetes` observations.

# %% [markdown]
# #### Model Creation

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
_ = model.fit(simple_X_train, y_train)

# %% [markdown]
# #### Model Execution

# %%
simple_y_pred = model.predict(simple_X_test)

# %% [markdown]
# #### Model Evaluation

# %% [markdown]
# First, we'll plot our predicted values alongside the observed values, as well as the regression line estimated by our model.

# %%
# Create figure
fig, ax = plt.subplots(figsize=(15, 7))

# Plot real values scatter plot
_ = plt.scatter(simple_X_test, y_test, color="black", label="Real Values")

# Plot predicted values scatter plot
_ = plt.scatter(simple_X_test,
                simple_y_pred,
                color="red",
                label="Predicted Values")

# Plot regression line
_ = plt.plot(simple_X_test,
             simple_y_pred,
             color="blue",
             label="Regression Line")

# Show legend
_ = plt.legend()

# Set title
title = "Disease Progression by BMI"
_ = plt.title(title)

# Sex axis labels
_ = ax.set_xlabel("Standardized BMI score")
_ = ax.set_ylabel("Disease Progression")

plt.show()

# %% [markdown]
# We can also use the [`sklearn.metrics`](https://scikit-learn.org/stable/modules/model_evaluation.html) module to calculate the [MSE](https://en.wikipedia.org/wiki/Mean_squared_error) and [coefficient of determination](https://en.wikipedia.org/wiki/Coefficient_of_determination) ($R^2$).

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, simple_y_pred)
r2_score_ = r2_score(y_test, simple_y_pred)
print(f"Coefficient: {model.coef_[0]:.2f}")
print(f'Mean Squared Error: {mse:.2f}')
print(f"Coefficient of Determination (R^2): {r2_score_:.2f}")
# Out:
# Coefficient: 981.66
# Mean Squared Error: 4150.68
# Coefficient of Determination (R^2): 0.19

# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# General notation:

# %% [markdown]
# ![OLS](https://wikimedia.org/api/rest_v1/media/math/render/svg/5d4d7a9152344a9b203e651e82834c16cb085365)

# %% [markdown]
# Calculating the coefficient vector of the least-squares hyperplane:

# %% [markdown]
# ![OLS beta hat](https://wikimedia.org/api/rest_v1/media/math/render/svg/b6001f896b83cf90fdc5c544743ceec61b7c83fd)

# %% [markdown]
# #### Manual Implementation

# %% [markdown]
# While it is always best to use the standard tools Python offers, let's be educationally paranoid for a minute and create our own implementation of ordinary least-squared (OLS) multiple linear regression.

# %% [markdown]
# A simplist implementation might look something like:

# %% [markdown]
# ```{margin}
# This code is adapted from Chapter 3 of Machine Learning: An Algorithmic Perspective (2nd Edition) by Stephen Marsland ([website](http://stephenmonika.net), [code source](https://github.com/alexsosn/MarslandMLAlgo/blob/master/Ch3/linreg.py)).
# ```

# %% [markdown]
# ```{literalinclude} manual_linear_regression.py
#     :lines: 1-62
# ```

# %% [markdown]
# ```{margin}
# The `@` operator actually calls the [`np.matmul()`](https://numpy.org/doc/stable/reference/generated/numpy.matmul.html#numpy.matmul) function rather than [`np.dot()`](https://numpy.org/doc/stable/reference/generated/numpy.dot.html#numpy.dot), however, because we don't use 3 (or higher) dimension arrays, the two functions behave the same in our use case.
# ```

# %% [markdown]
# Another version, which better conforms with standard implementations in machine learning models, might look something like:

# %% [markdown]
# ```{literalinclude} manual_linear_regression.py
#     :pyobject: ManualLinearRegression
# ```

# %% [markdown]
# ##### Model Execution

# %%
from manual_linear_regression import calculate_predictions, estimate_coefficients

# %%
beta_hat = estimate_coefficients(X_train, y_train)
y_pred_manual = calculate_predictions(X_test, beta_hat)

# %% [markdown]
# or:

# %%
from manual_linear_regression import ManualLinearRegression

# %%
manual_model = ManualLinearRegression()
manual_model.fit(X_train, y_train)
y_pred_manual = manual_model.predict(X_test)

# %% [markdown]
# ##### Model Evaluation

# %% [markdown]
# ###### $R^2$

# %% [markdown]
# Calculate the [residual sum of squares](https://en.wikipedia.org/wiki/Residual_sum_of_squares) ($RSS$):

# %% [markdown]
# ````{panels}
# General notation
# ^^^
# ![RSS general notation](https://wikimedia.org/api/rest_v1/media/math/render/svg/f8852833a56a9b55fdf5d6b2521eaec45274bab8)
# ---
# Matrix notation
# ^^^
# ![RSS linear notation](https://wikimedia.org/api/rest_v1/media/math/render/svg/68936d9b62f488dcc66120282485c13a0755bf3d)
# ````

# %%
ss_residual = np.sum((y_test - y_pred_manual)**2)
ss_residual
# Out:
# 304764.1852510224

# %% [markdown]
# Calculate the [total sum of squares](https://en.wikipedia.org/wiki/Total_sum_of_squares) ($TSS$):

# %% [markdown]
# ![TSS](https://wikimedia.org/api/rest_v1/media/math/render/svg/24f49fd012d7208436fc502fdb1f0065605951e6)

# %%
ss_total = np.sum((y_test - y_test.mean())**2)
ss_total
# Out:
# 456385.5056179776

# %% [markdown]
# Calculate $R^2$:

# %% [markdown]
# ![R squared](https://wikimedia.org/api/rest_v1/media/math/render/svg/c7e3ab84636f38c257641f85f009bcb422c73151)

# %%
r2_score_manual = 1 - ss_residual / ss_total
r2_score_manual
# Out:
# 0.3322220326906513

# %% [markdown]
# Compare with `sklearn`'s built-in `r2_score` function:

# %%
r2_score(y_true=y_test, y_pred=y_pred_manual)
# Out:
# 0.3322220326906513

# %% [markdown]
# ###### Mean Squared Error

# %% [markdown]
# Manual $MSE$ calculation:

# %%
mse_manual = np.mean((y_test - y_pred_manual)**2)
mse_manual
# Out:
# 3424.316688213735

# %% [markdown]
# Or using `sklearn`:

# %%
mean_squared_error(y_test, y_pred_manual)
# Out:
# 3424.316688213735

# %% [markdown]
# #### Multiple Linear Regression using `sklearn`

# %% [markdown]
# ##### Model Creation

# %% [markdown]
# We'll need to [`reshape`](https://numpy.org/devdocs/reference/generated/numpy.ndarray.reshape.html) our target vector:

# %% [markdown]
# ```{margin}
# For more information, see [this SO answer](https://stackoverflow.com/a/42510505).
# ```

# %%
y = y.to_numpy().reshape(-1, 1)

# %% [markdown]
# And now we're ready to fit the linear regression model, identically to our own object-oriented implementation:

# %%
multiple_model = LinearRegression()
_ = multiple_model.fit(X_train, y_train)

# %% [markdown]
# ##### Model Execution

# %%
y_pred_all = multiple_model.predict(X_test)

# %% [markdown]
# ##### Model Evaluation

# %%
mse_all = mean_squared_error(y_test, y_pred_all)
r2_score_all = r2_score(y_test, y_pred_all)

# %%
betas_all_repr = [beta.round(2) for beta in multiple_model.coef_.flatten()]

print(f"Coefficient: {betas_all_repr}")
print(f'Mean Squared Error: {mse_all:.2f}')
print(f"Coefficient of Determination (R^2): {r2_score_all:.2f}")
# Out:
# Coefficient: [-35.56, -243.17, 562.75, 305.47, -662.79, 324.28, 24.78, 170.33, 731.68, 43.03]
# Mean Squared Error: 3424.32
# Coefficient of Determination (R^2): 0.33
