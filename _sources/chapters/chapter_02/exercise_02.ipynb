# %% [markdown]
# # Exercise II: K-Nearest Neighbors (KNN)

# %% [markdown]
# [KNN](https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm) is a simple and useful non-parametric method that is commonly used for both classification and regression. It relies on having some method of calculating distance between data points, and using the the "nearest" observations to predict the target value for new ones.

# %% [markdown]
# <figure>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e7/KnnClassification.svg/1024px-KnnClassification.svg.png" alt="KNN Illustration" width="400"/>
#     <figcaption>
#         <i>
#             Example of k-NN classification. The test sample (green dot) should be classified either to blue squares or to red triangles. If k = 3 (solid line circle) it is assigned to the red triangles because there are 2 triangles and only 1 square inside the inner circle. If k = 5 (dashed line circle) it is assigned to the blue squares (3 squares vs. 2 triangles inside the outer circle).
#             <a href="https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm">
#                 Wikipedia
#             </a>
#         </i>
#     </figcaption>
# </figure>

# %% [markdown]
# ```{admonition} The Curse of Dimensionality
#     :class: note
# > *The curse of dimensionality refers to various phenomena that arise when analyzing and organizing data in high-dimensional spaces that do not occur in low-dimensional settings such as the three-dimensional physical space of everyday experience. [Wikipedia](https://en.wikipedia.org/wiki/Curse_of_dimensionality)*
#
# **KNN normally performs better with a limited number of features**. In simplified terms, distances become increasingly large in higher dimensionality spaces.
# ```

# %% [markdown]
# ## Loading the Dataset

# %% [markdown]
# In this exercise we will use the [Iris Flower Dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set). This dataset is commonly used for demonstrating simple statistical concepts and therefore `scikit-learn` provides us with a utility function to load it.

# %%
import pandas as pd

from sklearn.datasets import load_iris

TARGET_NAME = "class"

# Read a type of dictionary with the dataset as well as some metadata.
iris_dataset = load_iris()

# Read the features and targets.
X = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
y = pd.Series(iris_dataset.target, name=TARGET_NAME)

# %% [markdown]
# ## Basic Exploration

# %%
print(iris_dataset.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %% [markdown]
# ![Sepal and petal lengths](https://miro.medium.com/max/362/1*XN85Vu-SmkJc3TkwgTx5Kw.jpeg)

# %%
import numpy as np

# Set Pandas floating point display precision.
pd.set_option("precision", 2)

# Class colors
COLORS = "rgba(255, 0, 0, 0.3)", "rgba(0, 255, 0, 0.3)", "rgba(0, 0, 255, 0.3)"

# Create a unified dataframe.
data = pd.concat([X, y], axis="columns")

# Set class background color
def set_class_color(class_index: str) -> str:
    return f"background-color: {COLORS[class_index]};"

def set_class_name(class_index: str) -> str:
    return iris_dataset.target_names[class_index]

# Select some sample indices
sample_indices = np.linspace(0, len(data) - 5, 3, dtype=int)
sample_indices = [index for i in sample_indices for index in range(i, i + 5)]

# Display table
data.iloc[sample_indices, :].style.background_gradient(
).applymap(
    set_class_color, subset=[TARGET_NAME]    
).format(
    set_class_name, subset=[TARGET_NAME]
).set_properties(
    **{"border": "1px solid black"}, subset=[TARGET_NAME]
).set_properties(
    **{"text-align": "center"}
).set_table_styles([
    dict(selector="th", props=[("font-size", "14px")]),
    dict(selector="td", props=[("font-size", "12px")]),
])
# Out:
# <style  type="text/css" >
#     #T_0cf7c612_28f4_11eb_8714_dfbde11d4e1d th {
#           font-size: 14px;
#     }    #T_0cf7c612_28f4_11eb_8714_dfbde11d4e1d td {
#           font-size: 12px;
#     }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow0_col0{
#             background-color:  #d5d5e8;
#             color:  #000000;
#             background-color:  #023858;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow5_col0,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow11_col0{
#             background-color:  #056caa;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow5_col2{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow5_col3{
#             background-color:  #3991c1;
#             color:  #000000;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow5_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow6_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow7_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow8_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow9_col4{
#             background-color:  #73a9cf;
#             color:  #000000;
#             background-color:  rgba(0, 255, 0, 0.3);
#             border:  1px solid black;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow6_col0{
#             background-color:  #2081b9;
#             color:  #000000;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow6_col1,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow9_col1{
#             background-color:  #c9cee4;
#             color:  #000000;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow6_col2{
#             background-color:  #046299;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow6_col3{
#             background-color:  #7eadd1;
#             color:  #000000;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow7_col0,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow13_col1{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow7_col1{
#             background-color:  #a9bfdc;
#             color:  #000000;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow7_col2{
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow7_col3{
#             background-color:  #67a4cc;
#             color:  #000000;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow8_col2{
#             background-color:  #056fae;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow8_col3,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow9_col3{
#             background-color:  #509ac6;
#             color:  #000000;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow9_col2{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow10_col0{
#             background-color:  #03446a;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow10_col2,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow12_col2{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow10_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow11_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow12_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow13_col4,#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow14_col4{
#             background-color:  #023858;
#             color:  #f1f1f1;
#             background-color:  rgba(0, 0, 255, 0.3);
#             border:  1px solid black;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow11_col2{
#             background-color:  #045280;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow11_col3{
#             background-color:  #05659f;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow12_col0{
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow12_col3{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow13_col0{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#             text-align:  center;
#         }#T_0cf7c612_28f4_11eb_8714_dfbde11d4e1drow14_col0{
#             backgr

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
X.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count             150.00            150.00             150.00
# mean                5.84              3.06               3.76
# std                 0.83              0.44               1.77
# min                 4.30              2.00               1.00
# 25%                 5.10              2.80               1.60
# 50%                 5.80              3.00               4.35
# 75%                 6.40              3.30               5.10
# max                 7.90              4.40               6.90
#
#        petal width (cm)
# count            150.00
# mean               1.20
# std                0.76
# min                0.10
# 25%                0.30
# 50%                1.30
# 75%                1.80
# max                2.50

# %%
from matplotlib.colors import ListedColormap

cmap = ListedColormap([(1, 0, 0), (0, 1, 0), (0, 0, 1)])
_ = pd.plotting.scatter_matrix(X,
                               c=y,
                               cmap=cmap,
                               figsize=(15, 15),
                               marker='o',
                               hist_kwds={'bins': 20},
                               s=60,
                               alpha=.4)

# %% [markdown]
# ## Train/Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=0,
                                                    test_size=0.25)

# %%
from myst_nb import glue

glue("n_train", len(X_train), display=False)
glue("n_test", len(X_test), display=False)

# %% [markdown]
# We now have a training dataset consisting of {glue:}`n_train` observations and a test dataset with {glue:}`n_test` observations.

# %% [markdown]
# ## Model Creation

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
_ = knn.fit(X_train, y_train)

# %% [markdown]
# ## Model Evaluation

# %%
import numpy as np

y_predicted = knn.predict(X_test)

misclassification_rate = np.mean(y_predicted != y_test)

# %%
glue("misclassification_rate", f"{misclassification_rate:.3f}", display=False)
glue("n_correct", (y_predicted == y_test).sum(), display=False)

# %% [markdown]
# Our model achieved a misclassification_rate of {glue:}`misclassification_rate`, meaning it correctly predicted {glue:}`n_correct` of {glue:}`n_test` target values in our test set.

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import plot_confusion_matrix

disp = plot_confusion_matrix(knn,
                             X_test,
                             y_test,
                             display_labels=iris_dataset.target_names,
                             cmap=plt.cm.Blues,
                             normalize="true")
_ = disp.ax_.set_title("Confusion Matrix (k=1)")
